# %%
import pandas as pd
import requests

# %%
key = "otqvshn22qrt"
regionCode = "CL"

url = f"https://api.ebird.org/v2/ref/taxonomy/ebird"

payload={}
headers = {
  'X-eBirdApiToken': key
}
response = requests.request("GET", url, headers=headers, data=payload)

# %%
text = response.text

# %%
a = text.split("\n")
headers = a[0].split(",")
body = a[1:]

# %%
body_aux = []
for i in range(len(body)):
    body[i] = body[i].split(",")
    if len(body[i]) == 15:
        body_aux.append(body[i])
body = body_aux

# %%
df = pd.DataFrame(body, columns=headers)

# %%
df
# Out:
#                       SCIENTIFIC_NAME              COMMON_NAME SPECIES_CODE  \
# 0                    Struthio camelus           Common Ostrich      ostric2
# 1              Struthio molybdophanes           Somali Ostrich      ostric3
# 2      Struthio camelus/molybdophanes    Common/Somali Ostrich       y00934
# 3                      Rhea americana             Greater Rhea      grerhe1
# 4                        Rhea pennata              Lesser Rhea      lesrhe2
# ...                               ...                      ...          ...
# 13747                Saltator grossus   Slate-colored Grosbeak      slcgro1
# 13748            Saltator fuliginosus  Black-throated Grosbeak      bltgro2
# 13749                    Saltator sp.             saltator sp.      saltat1
# 13750               Passeriformes sp.            passerine sp.      passer1
# 13751                        Aves sp.                 bird sp.        bird1
#
#       CATEGORY TAXON_ORDER COM_NAME_CODES SCI_NAME_CODES BANDING_CODES  \
# 0      species         2.0           COOS           STCA
# 1      species         7.0           SOOS           STMO
# 2        slash         8.0      SOOS COOS      STCA STMO
# 3      species        10.0           GRRH           RHAM
# 4      species        16.0           LERH           RHPE
# ...        ...         ...            ...            ...           ...
# 13747  species     35127.0           SCGR           SAGR          SCOG
# 13748  species     35130.0           BTGR           SAFU
# 13749     spuh     35131.0
# 13750     spuh     35132.0
# 13751     spuh     35133.0                                        UNBI
#
#                   ORDER      FAMILY_COM_NAME FAMILY_SCI_NAME REPORT_AS  \
# 0      Struthioniformes            Ostriches   Struthionidae
# 1      Struthioniformes            Ostriches   Struthionidae
# 2      Struthioniformes            Ostriches   Struthionidae
# 3            Rheiformes                Rheas         Rheidae
# 4            Rheiformes                Rheas         Rheidae
# ...                 ...                  ...             ...       ...
# 13747     Passeriformes  Tanagers and Allies      Thraupidae
# 13748     Passeriformes  Tanagers and Allies      Thraupidae
# 13749     Passeriformes  Tanagers and Allies      Thraupidae
# 13750     Passeriformes
# 13751
#
#       EXTINCT EXTINCT_YEAR FAMILY_CODE
# 0                              struth1
# 1                              struth1
# 2                              struth1
# 3                              rheida1
# 4                              rheida1
# ...       ...          ...         ...
# 13747                          thraup2
# 13748                          thraup2
# 13749                          thraup2
# 13750
# 13751
#
# [13752 rows x 15 columns]

# %%
df.to_csv("taxonomia.csv", index=False)
