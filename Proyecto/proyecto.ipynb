# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import os

# %%
with open("Proyecto1 - Manufactured.csv") as weapons_data:
    weapons_data = pd.read_csv(weapons_data)

weapons_data
# Out:
#          Year    Pistols  Revolvers Total Handguns      Rifles    Shotguns  \
# 0   1899-1945        NaN        NaN     11,722,000  20,651,000  13,338,000
# 1        1946        NaN        NaN            176         729         621
# 2        1947        NaN        NaN            257         953         860
# 3        1948        NaN        NaN            427   1,170,000   1,013,000
# 4        1949        NaN        NaN            256         862   1,050,000
# ..        ...        ...        ...            ...         ...         ...
# 72       2017  3,691,010    720,917      4,411,927   2,504,092     653,139
# 73       2018  3,881,158    664,835      4,545,993   2,880,536     536,126
# 74       2019  3,046,013    580,601      3,626,614   1,957,667     480,735
# 75       2020  5,509,183    993,078      6,502,261   2,760,392     476,682
# 76       2021  6,751,919  1,159,918      7,911,837   3,934,374     675,426
#
#    Total Long Guns Misc. Firearms Total Manufactured
# ...
