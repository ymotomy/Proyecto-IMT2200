# %%
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = 10

# %%
df1 = pd.read_csv('FOFA2050CountryData_Crop-production.csv')
df1= df1[df1['CountryName'] == 'Chile']
df1
# Out:
#                  Domain           Indicator                         Item  \
# 92475   Crop Production         Arable land            Growing of barley
# 92476   Crop Production         Arable land            Growing of barley
# 92477   Crop Production         Arable land            Growing of barley
# 92478   Crop Production         Arable land            Growing of barley
# 92479   Crop Production         Arable land            Growing of barley
# ...                 ...                 ...                          ...
# 183910  Crop Production  Technology shifter  Growing of other vegetables
# 183911  Crop Production  Technology shifter  Growing of other vegetables
# 183912  Crop Production  Technology shifter  Growing of other vegetables
# 183913  Crop Production  Technology shifter  Growing of other vegetables
# 183914  Crop Production  Technology shifter  Growing of other vegetables
#
#           Element CountryCode CountryName       Region               Scenario  \
# ...

# %%
df2 = pd.read_csv('FOFA2050CountryData_Fertilizer-and-emissions.csv')
df2= df2[df2['CountryName'] == 'Chile']
df2
# Out:
#                         Domain                     Indicator             Item  \
# 990   Fertilizer and Emissions               NPK Consumption  NPK_consumption
# 991   Fertilizer and Emissions               NPK Consumption  NPK_consumption
# 992   Fertilizer and Emissions               NPK Consumption  NPK_consumption
# 993   Fertilizer and Emissions               NPK Consumption  NPK_consumption
# 994   Fertilizer and Emissions               NPK Consumption  NPK_consumption
# ...                        ...                           ...              ...
# 1570  Fertilizer and Emissions  GHG emissions in agriculture            Total
# 1571  Fertilizer and Emissions  GHG emissions in agriculture            Total
# 1572  Fertilizer and Emissions  GHG emissions in agriculture            Total
# 1573  Fertilizer and Emissions  GHG emissions in agriculture            Total
# 1574  Fertilizer and Emissions  GHG emissions in agriculture            Total
#
# ...

# %%
df3 = pd.read_csv('FOFA2050CountryData_Food-security.csv')
df3= df3[df3['CountryName'] == 'Chile']
df3
# Out:
#               Domain                           Indicator   Item  \
# 27495  Food Security    Daily energy supply by commodity    ALL
# 27496  Food Security    Daily energy supply by commodity    ALL
# 27497  Food Security    Daily energy supply by commodity    ALL
# 27498  Food Security    Daily energy supply by commodity    ALL
# 27499  Food Security    Daily energy supply by commodity    ALL
# ...              ...                                 ...    ...
# 65755  Food Security  Percentage of Undernourished (PoU)  Total
# 65756  Food Security  Percentage of Undernourished (PoU)  Total
# 65757  Food Security  Percentage of Undernourished (PoU)  Total
# 65758  Food Security  Percentage of Undernourished (PoU)  Total
# 65759  Food Security  Percentage of Undernourished (PoU)  Total
#
#                               Element CountryCode CountryName       Region  \
# 27495             Daily energy supply         CHL       Chile  High-income
# ...

# %%
df4 = pd.read_csv('FOFA2050CountryData_Livestock.csv')
df4= df4[df4['CountryName'] == 'Chile']
df4
# Out:
#           Domain     Indicator               Item Element CountryCode  \
# 6630   Livestock  Productivity  Raising of cattle    Beef         CHL
# 6631   Livestock  Productivity  Raising of cattle    Beef         CHL
# 6632   Livestock  Productivity  Raising of cattle    Beef         CHL
# 6633   Livestock  Productivity  Raising of cattle    Beef         CHL
# 6634   Livestock  Productivity  Raising of cattle    Beef         CHL
# ...          ...           ...                ...     ...         ...
# 13150  Livestock    Herd sizes    Livestock units   Total         CHL
# 13151  Livestock    Herd sizes    Livestock units   Total         CHL
# 13152  Livestock    Herd sizes    Livestock units   Total         CHL
# 13153  Livestock    Herd sizes    Livestock units   Total         CHL
# 13154  Livestock    Herd sizes    Livestock units   Total         CHL
#
#       CountryName       Region               Scenario           Units  Year  \
# ...

# %%
df5 = pd.read_csv('FOFA2050CountryData_Macro-indicators.csv')
df5= df5[df5['CountryName'] == 'Chile']
df5
# Out:
#                 Domain       Indicator   Item               Element  \
# 990   Macro Indicators  GDP per capita  Total  GDP at market prices
# 991   Macro Indicators  GDP per capita  Total  GDP at market prices
# 992   Macro Indicators  GDP per capita  Total  GDP at market prices
# 993   Macro Indicators  GDP per capita  Total  GDP at market prices
# 994   Macro Indicators  GDP per capita  Total  GDP at market prices
# ...                ...             ...    ...                   ...
# 1570  Macro Indicators      Population  Total      Total population
# 1571  Macro Indicators      Population  Total      Total population
# 1572  Macro Indicators      Population  Total      Total population
# 1573  Macro Indicators      Population  Total      Total population
# 1574  Macro Indicators      Population  Total      Total population
#
#      CountryCode CountryName       Region               Scenario  \
# 990          CHL       Chile  High-income  Toward Sustainability
# ...
