# %%
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = 5

# %%
df = pd.read_csv('FAOLEX_Food.csv')
df = df[df['Country/Territory'] == 'Chile']
df
# Out:
#             Record Id                                         Record URL  \
# 20     LEX-FAOC002590  http://www.fao.org/faolex/results/details/en/c...
# 124    LEX-FAOC003823  http://www.fao.org/faolex/results/details/en/c...
# ...               ...                                                ...
# 35680  LEX-FAOC209049  http://www.fao.org/faolex/results/details/en/c...
# 35815  LEX-FAOC216076  http://www.fao.org/faolex/results/details/en/c...
#
#                                         Document URL  \
# 20       https://faolex.fao.org/docs/pdf/chi2590.pdf
# 124      https://faolex.fao.org/docs/pdf/chi3823.pdf
# ...                                              ...
# 35680  https://faolex.fao.org/docs/pdf/chi209049.pdf
# 35815  https://faolex.fao.org/docs/pdf/chi216076.pdf
#
#                                                    Title Original title  \
# 20     Decreto Nº 276 - Reglamento de rotulación de l...            NaN
# 124    Decreto Nº 244 - Reglamento para las transacci...            NaN
# ...                                                  ...            ...
# 35680  Estrategia de Sustentabilidad Agroalimentaria ...            NaN
# 35815  Estrategia Climática de Largo Plazo de Chile: ...            NaN
#
#       Date of original text Last amended date  \
# 20               26-08-1986               NaN
# 124              29-07-1985               NaN
# ...                     ...               ...
# 35680                  2020               NaN
# 35815                  2021               NaN
#
#                             Available website Language of document  \
# 20                                        NaN              Spanish
# 124                                       NaN              Spanish
# ...                                       ...                  ...
# 35680  https://bibliotecadigital.odepa.gob.cl              Spanish
# 35815      https://cambioclimatico.mma.gob.cl              Spanish
#
#       Country/Territory Regional organizations Territorial subdivision  \
# 20                Chile                    NaN                     NaN
# 124               Chile                    NaN                     NaN
# ...                 ...                    ...                     ...
# 35680             Chile                    NaN                     NaN
# 35815             Chile                    NaN                     NaN
#
#       Type of text Repealed  \
# 20      Regulation      NaN
# 124     Regulation      NaN
# ...            ...      ...
# 35680       Policy      NaN
# 35815       Policy      NaN
#
#                                                 Abstract  \
# 20     El Decreto establece que todos los envases de ...
# 124    El Decreto, que consta de 9 artículos, aprueba...
# ...                                                  ...
# 35680  El presente documento contiene la Estrategia d...
# 35815  La presente Estrategia Climática se constituye...
#
#                                         Primary subjects  \
# 20                                      Food & nutrition
# 124                                     Food & nutrition
# ...                                                  ...
# 35680  Agricultural & rural development; Food & nutri...
# 35815                                     Climate change
#
#                                                   Domain  \
# 20                                      Food & nutrition
# 124                                     Food & nutrition
# ...                                                  ...
# 35680  Agriculture; Air & atmosphere; Environment; Fo...
# 35815  Agriculture; Livestock; Energy; Environment; F...
#
#                                                 Keywords
# 20              packaging/labelling; cereals/grains/rice
# 124    food safety and quality; cereals/grains/rice; ...
# ...                                                  ...
# 35680  innovation; education; financing; monitoring; ...
# 35815  capacity building; extension; education; ecofr...
#
# [435 rows x 18 columns]

# %%
for column in df.columns:
    if len(df[column].unique()) <= 3:
        # df.drop(column, axis=1, inplace=True)
        print(column)
# Out:
# Repealed
