# %%
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = 5

# %%
df =  pd.read_csv("Proyecto de ley de agricultura CHILE.csv")
df
# Out:
#            Record Id                                         Record URL  \
# 0     LEX-FAOC061452  http://www.fao.org/faolex/results/details/en/c...
# 1     LEX-FAOC205091  http://www.fao.org/faolex/results/details/en/c...
# ...              ...                                                ...
# 2586  LEX-FAOC169602  http://www.fao.org/faolex/results/details/en/c...
# 2587  LEX-FAOC209049  http://www.fao.org/faolex/results/details/en/c...
#
#                                        Document URL  \
# 0      https://faolex.fao.org/docs/pdf/chi61452.pdf
# 1     https://faolex.fao.org/docs/pdf/chi205091.pdf
# ...                                             ...
# 2586  https://faolex.fao.org/docs/pdf/chi169602.pdf
# 2587  https://faolex.fao.org/docs/pdf/chi209049.pdf
#
#                                                   Title  Original title  \
# 0     Ley Nº 20.089 - Crea Sistema Nacional de Certi...             NaN
# 1                                         Código Civil.             NaN
# ...                                                 ...             ...
# 2586  Plan de Acción Nacional de Cambio Climático 20...             NaN
# 2587  Estrategia de Sustentabilidad Agroalimentaria ...             NaN
#
#      Date of original text Last amended date  \
# 0               21-12-2005        30-05-2015
# 1               14-12-1855        11-09-2020
# ...                    ...               ...
# 2586                  2008               NaN
# 2587                  2020               NaN
#
#                            Available website Language of document  \
# 0                            www.leychile.cl              Spanish
# 1                       https://leyes-cl.com              Spanish
# ...                                      ...                  ...
# 2586                http://portal.mma.gob.cl              Spanish
# 2587  https://bibliotecadigital.odepa.gob.cl              Spanish
#
#      Country/Territory  Regional organizations  Territorial subdivision  \
# 0                Chile                     NaN                      NaN
# 1                Chile                     NaN                      NaN
# ...                ...                     ...                      ...
# 2586             Chile                     NaN                      NaN
# 2587             Chile                     NaN                      NaN
#
#      Type of text Repealed                                           Abstract  \
# 0     Legislation      NaN  La presente Ley tiene por objeto la creación y...
# 1     Legislation      NaN  El Código Civil Chileno fue uno de los primero...
# ...           ...      ...                                                ...
# 2586       Policy      NaN  El presente Plan de Acción Nacional de Cambio ...
# 2587       Policy      NaN  El presente documento contiene la Estrategia d...
#
#                                        Primary subjects  \
# 0                      Agricultural & rural development
# 1                     Private sector & entrepreneurship
# ...                                                 ...
# 2586                                     Climate change
# 2587  Agricultural & rural development; Food & nutri...
#
#                                                  Domain  \
# 0     Agriculture; Livestock; Food & nutrition; Fore...
# 1     Agriculture; Livestock; Forestry; Land & soil;...
# ...                                                 ...
# 2586  Agriculture; Air & atmosphere; Energy; Environ...
# 2587  Agriculture; Air & atmosphere; Environment; Fo...
#
#                                                Keywords
# 0     ecological production/organic production; ecol...
# 1     Civil Code; contracts; inheritance; gender; ag...
# ...                                                 ...
# 2586  climate change; climate change; risk assessmen...
# 2587  innovation; education; financing; monitoring; ...
#
# [2588 rows x 18 columns]

# %%
for column in df.columns:
    if len(df[column].unique()) == 1:
        df.drop(column, axis=1, inplace=True)

# %%
df
# Out:
#            Record Id                                         Record URL  \
# 0     LEX-FAOC061452  http://www.fao.org/faolex/results/details/en/c...
# 1     LEX-FAOC205091  http://www.fao.org/faolex/results/details/en/c...
# ...              ...                                                ...
# 2586  LEX-FAOC169602  http://www.fao.org/faolex/results/details/en/c...
# 2587  LEX-FAOC209049  http://www.fao.org/faolex/results/details/en/c...
#
#                                        Document URL  \
# 0      https://faolex.fao.org/docs/pdf/chi61452.pdf
# 1     https://faolex.fao.org/docs/pdf/chi205091.pdf
# ...                                             ...
# 2586  https://faolex.fao.org/docs/pdf/chi169602.pdf
# 2587  https://faolex.fao.org/docs/pdf/chi209049.pdf
#
#                                                   Title Date of original text  \
# 0     Ley Nº 20.089 - Crea Sistema Nacional de Certi...            21-12-2005
# 1                                         Código Civil.            14-12-1855
# ...                                                 ...                   ...
# 2586  Plan de Acción Nacional de Cambio Climático 20...                  2008
# 2587  Estrategia de Sustentabilidad Agroalimentaria ...                  2020
#
#      Last amended date                       Available website  \
# 0           30-05-2015                         www.leychile.cl
# 1           11-09-2020                    https://leyes-cl.com
# ...                ...                                     ...
# 2586               NaN                http://portal.mma.gob.cl
# 2587               NaN  https://bibliotecadigital.odepa.gob.cl
#
#      Language of document Type of text Repealed  \
# 0                 Spanish  Legislation      NaN
# 1                 Spanish  Legislation      NaN
# ...                   ...          ...      ...
# 2586              Spanish       Policy      NaN
# 2587              Spanish       Policy      NaN
#
#                                                Abstract  \
# 0     La presente Ley tiene por objeto la creación y...
# 1     El Código Civil Chileno fue uno de los primero...
# ...                                                 ...
# 2586  El presente Plan de Acción Nacional de Cambio ...
# 2587  El presente documento contiene la Estrategia d...
#
#                                        Primary subjects  \
# 0                      Agricultural & rural development
# 1                     Private sector & entrepreneurship
# ...                                                 ...
# 2586                                     Climate change
# 2587  Agricultural & rural development; Food & nutri...
#
#                                                  Domain  \
# 0     Agriculture; Livestock; Food & nutrition; Fore...
# 1     Agriculture; Livestock; Forestry; Land & soil;...
# ...                                                 ...
# 2586  Agriculture; Air & atmosphere; Energy; Environ...
# 2587  Agriculture; Air & atmosphere; Environment; Fo...
#
#                                                Keywords
# 0     ecological production/organic production; ecol...
# 1     Civil Code; contracts; inheritance; gender; ag...
# ...                                                 ...
# 2586  climate change; climate change; risk assessmen...
# 2587  innovation; education; financing; monitoring; ...
#
# [2588 rows x 14 columns]
