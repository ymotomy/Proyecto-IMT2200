# %%
import pandas as pd
import requests

# %%
def anho(y):
    print(" ")
    key = "otqvshn22qrt"
    regionCode = "CL"
    payload={}
    headers = {
        'X-eBirdApiToken': key
    }
    df = pd.DataFrame()
    for m in range(1, 13):
        for d in range(1, 32):
            print(f"{d}-{m}-{y}", end=" ; ")
            url = url = f"https://api.ebird.org/v2/data/obs/{regionCode}/historic/{y}/{m}/{d}"
            response = requests.request("GET", url, headers=headers, data=payload)
            df = pd.concat([df, pd.json_normalize(response.json())], ignore_index=True)
    return df

# %%
for y in range(2019, 2022):
    df = anho(y)
    df.to_csv(f"vis_{y}.csv", index=False)

# %%
df_2019 = pd.read_csv("vis_2019.csv")
df_2020 = pd.read_csv("vis_2020.csv")

# %%
df_2019
# Out:
#       speciesCode                      comName               sciName  \
# 0         soulap1             Southern Lapwing    Vanellus chilensis
# 1          brnowl                     Barn Owl             Tyto alba
# 2         aupowl1            Austral Pygmy-Owl       Glaucidium nana
# 3         austhr1               Austral Thrush    Turdus falcklandii
# 4         whcela1        White-crested Elaenia      Elaenia albiceps
# ...           ...                          ...                   ...
# 62676      verfly         Vermilion Flycatcher  Pyrocephalus rubinus
# 62677     slbfin3         Slender-billed Finch  Xenospingus concolor
# 62678     blbgra1         Blue-black Grassquit    Volatinia jacarina
# 62679     chtsee1  Chestnut-throated Seedeater    Sporophila telasco
# 62680     perter2                Peruvian Tern       Sternula lorata
#
#            locId                                            locName  \
# 0       L4026975                                         Loma Linda
# 1       L4026975                                         Loma Linda
# 2       L4026975                                         Loma Linda
# 3       L7488647                                 Plaza Melvin Jones
# 4       L8346445  1485 Loncoyen, Valdivia, Región de los Ríos, C...
# ...          ...                                                ...
# 62676    L760571                                              Azapa
# 62677    L760571                                              Azapa
# 62678    L760571                                              Azapa
# 62679    L760571                                              Azapa
# 62680  L12031093                                           Hornitos
#
#                   obsDt  howMany        lat        lng obsValid obsReviewed  \
# 0      2019-01-01 23:00      1.0 -33.435764 -71.677103     True       False
# 1      2019-01-01 23:00      1.0 -33.435764 -71.677103     True       False
# 2      2019-01-01 23:00      1.0 -33.435764 -71.677103     True       False
# 3      2019-01-01 22:25      1.0 -33.451996 -70.593581     True       False
# 4      2019-01-01 22:05      NaN -39.824130 -73.278223     True       False
# ...                 ...      ...        ...        ...      ...         ...
# 62676  2019-12-31 08:10      2.0 -18.517247 -70.197006     True       False
# 62677  2019-12-31 08:10      1.0 -18.517247 -70.197006     True       False
# 62678  2019-12-31 08:10      1.0 -18.517247 -70.197006     True       False
# 62679  2019-12-31 08:10     10.0 -18.517247 -70.197006     True       False
# 62680  2019-12-31 07:20      1.0 -22.872257 -70.288054     True        True
#
#       locationPrivate      subId exoticCategory errors
# 0               False  S51197645            NaN    NaN
# 1               False  S51197645            NaN    NaN
# 2               False  S51197645            NaN    NaN
# 3               False  S51194229            NaN    NaN
# 4                True  S51192610            NaN    NaN
# ...               ...        ...            ...    ...
# 62676           False  S63139126            NaN    NaN
# 62677           False  S63139126            NaN    NaN
# 62678           False  S63139126            NaN    NaN
# 62679           False  S63139126            NaN    NaN
# 62680            True  S72204442            NaN    NaN
#
# [62681 rows x 15 columns]

# %%
ubicaciones = df_2019[["locName", "lat", "lng"]].drop_duplicates(df_2019.columns[df_2019.columns.isin(['locName'])],
                        keep='first')

# %%
ubicaciones
# Out:
#                                                  locName        lat        lng
# 0                                             Loma Linda -33.435764 -71.677103
# 3                                     Plaza Melvin Jones -33.451996 -70.593581
# 4      1485 Loncoyen, Valdivia, Región de los Ríos, C... -39.824130 -73.278223
# 5                                     (-35.594, -71.735) -35.593632 -71.735010
# 6                              Poniente--Calles y Plazas -33.537781 -70.561735
# ...                                                  ...        ...        ...
# 62618                                      Laguna Rivera -39.344536 -71.688309
# 62634              Dientes de Navarino--Laguna Betinelli -55.047450 -67.628789
# 62655                   Faro San Isidro--Cruz de froward -53.832784 -71.079483
# 62657                Pinto, Ñuble, CL (-36.878, -71.464) -36.878458 -71.463928
# 62664                             humedal brisas del sol -36.741205 -73.089563
#
# [7735 rows x 3 columns]

# %%
#https://nominatim.org/release-docs/develop/api/Overview/
def region(lat, lon):
    url = f'https://nominatim.openstreetmap.org/reverse?lat={lat}&lon={lon}&format=json'
    page = requests.get(url)
    json = page.json()
    region = json['address']['state']
    return region

# %%
ubicaciones["state"] = 0

# %%
ubicaciones['state'] = df_2019.apply(lambda x: region(x['lat'], x['lng']), axis=1)
ubicaciones
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\matar\OneDrive - Universidad Católica de Chile\Ramos\IMT2200 - Introduccion a Ciencia de Datos\Proyecto (git)\Aves\vis.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/matar/OneDrive%20-%20Universidad%20Cat%C3%B3lica%20de%20Chile/Ramos/IMT2200%20-%20Introduccion%20a%20Ciencia%20de%20Datos/Proyecto%20%28git%29/Aves/vis.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> ubicaciones['state'] = df_2019.apply(lambda x: region(x['lat'], x['lng']), axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/matar/OneDrive%20-%20Universidad%20Cat%C3%B3lica%20de%20Chile/Ramos/IMT2200%20-%20Introduccion%20a%20Ciencia%20de%20Datos/Proyecto%20%28git%29/Aves/vis.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> ubicaciones
#
# File c:\Users\matar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\matar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:831, in FrameApply.apply(self)
#     828 elif self.raw:
#     829     return self.apply_raw()
# --> 831 return self.apply_standard()
#
# File c:\Users\matar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:957, in FrameApply.apply_standard(self)
#     956 def apply_standard(self):
# --> 957     results, res_index = self.apply_series_generator()
#     959     # wrap results
#     960     return self.wrap_results(results, res_index)
#
# File c:\Users\matar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:973, in FrameApply.apply_series_generator(self)
#     970 with option_context("mode.chained_assignment", None):
#     971     for i, v in enumerate(series_gen):
#     972         # ignore SettingWithCopy here in case the user mutates
# --> 973         results[i] = self.func(v, *self.args, **self.kwargs)
#     974         if isinstance(results[i], ABCSeries):
#     975             # If we have a view on v, we need to make a copy because
#     976             #  series_generator will swap out the underlying data
#     977             results[i] = results[i].copy(deep=False)
#
# c:\Users\matar\OneDrive - Universidad Católica de Chile\Ramos\IMT2200 - Introduccion a Ciencia de Datos\Proyecto (git)\Aves\vis.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/matar/OneDrive%20-%20Universidad%20Cat%C3%B3lica%20de%20Chile/Ramos/IMT2200%20-%20Introduccion%20a%20Ciencia%20de%20Datos/Proyecto%20%28git%29/Aves/vis.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> ubicaciones['state'] = df_2019.apply(lambda x: region(x['lat'], x['lng']), axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/matar/OneDrive%20-%20Universidad%20Cat%C3%B3lica%20de%20Chile/Ramos/IMT2200%20-%20Introduccion%20a%20Ciencia%20de%20Datos/Proyecto%20%28git%29/Aves/vis.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> ubicaciones
#
# c:\Users\matar\OneDrive - Universidad Católica de Chile\Ramos\IMT2200 - Introduccion a Ciencia de Datos\Proyecto (git)\Aves\vis.ipynb Cell 10 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/matar/OneDrive%20-%20Universidad%20Cat%C3%B3lica%20de%20Chile/Ramos/IMT2200%20-%20Introduccion%20a%20Ciencia%20de%20Datos/Proyecto%20%28git%29/Aves/vis.ipynb#X25sZmlsZQ%3D%3D?line=3'>4</a> page = requests.get(url)
#       <a href='vscode-notebook-cell:/c%3A/Users/matar/OneDrive%20-%20Universidad%20Cat%C3%B3lica%20de%20Chile/Ramos/IMT2200%20-%20Introduccion%20a%20Ciencia%20de%20Datos/Proyecto%20%28git%29/Aves/vis.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> json = page.json()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/matar/OneDrive%20-%20Universidad%20Cat%C3%B3lica%20de%20Chile/Ramos/IMT2200%20-%20Introduccion%20a%20Ciencia%20de%20Datos/Proyecto%20%28git%29/Aves/vis.ipynb#X25sZmlsZQ%3D%3D?line=5'>6</a> region = json['address']['state']
#       <a href='vscode-notebook-cell:/c%3A/Users/matar/OneDrive%20-%20Universidad%20Cat%C3%B3lica%20de%20Chile/Ramos/IMT2200%20-%20Introduccion%20a%20Ciencia%20de%20Datos/Proyecto%20%28git%29/Aves/vis.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a> return region
#
# KeyError: 'state'
