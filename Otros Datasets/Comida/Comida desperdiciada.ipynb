# %%
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = 5

# %%
df = pd.read_csv('Comida desperdiciada.csv')
df = df[df['country'] == 'Chile']
df
# Out:
#       m49_code country                  region  cpc_code commodity  year  \
# 1512       152   Chile                     NaN     01510  Potatoes  2015
# 1513       152   Chile                     NaN     01510  Potatoes  2015
# 1514       152   Chile  North Patagonia Region  01342.01     Pears  2013
#
#       loss_percentage loss_percentage_original loss_quantity   activity  \
# 1512              1.3                     1.3%           NaN  Marketing
# 1513              5.7                     5.7%           NaN    Storage
# 1514             13.0                       13           NaN        NaN
#
#      food_supply_stage treatment  cause_of_loss              sample_size  \
# 1512         Wholesale       NaN            NaN                      NaN
# 1513           Storage       NaN            NaN                      NaN
# 1514              Farm       NaN  Insect Damage  5500 (individual pears)
#
#             method_data_collection  \
# 1512                        Survey
# ...
